# %%
# PC 3
# Lorena Belen Cerda Rioja

# %%
#link de repositorio, carpeta de archivos
Repo="https://github.com/Lorbe277/Control3_ICDE/raw/main/appendData"

# %%
# creando nombre de archivos a lista
level=range(1,5)
files=["level"+str(level)+'.xlsx' for level in level]
files
# Out:
# ['level1.xlsx', 'level2.xlsx', 'level3.xlsx', 'level4.xlsx']

# %%
# creando link para todos los archivo
alltheLinks=[Repo+"/"+fn for fn in files]
alltheLinks
# Out:
# ['https://github.com/Lorbe277/Control3_ICDE/raw/main/appendData/level1.xlsx',
#  'https://github.com/Lorbe277/Control3_ICDE/raw/main/appendData/level2.xlsx',
#  'https://github.com/Lorbe277/Control3_ICDE/raw/main/appendData/level3.xlsx',
#  'https://github.com/Lorbe277/Control3_ICDE/raw/main/appendData/level4.xlsx']

# %%
#creando link para cada archivo
file1, file2, file3, file4 = [enlace for enlace in alltheLinks]
file3
# Out:
# 'https://github.com/Lorbe277/Control3_ICDE/raw/main/appendData/level3.xlsx'

# %% [markdown]
# LIMPIEZA DE DFs

# %%
#Importacion de pandas
import pandas as pd
# Obtención de la tabla de Excel sin encabezado
data1 = pd.read_excel(file1, header=None)

#diferenciar HDI rank 2021 y 2020
data1.loc[4, 14] = "HDI rank 2020"

data1.head(9)
# Out:
#          0                                                  1   \
# 0       NaN  Table 1. Human Development Index and its compo...
# 1       NaN                                                NaN
# 2       NaN                                                NaN
# 3       NaN                                                NaN
# 4  HDI rank                                            Country
# 5       NaN                                                NaN
# 6       NaN                                                NaN
# 7         1                                        Switzerland
# 8         2                                             Norway
#
#                                2   3                         4    5   \
# 0                             NaN NaN                       NaN  NaN
# 1                             NaN NaN                       NaN  NaN
# 2                             NaN NaN                      SDG3  NaN
# ...

# %%
#seleccionar el encabezado
encabezado=data1.iloc[4]
data1.columns=encabezado
# Eliminar las filas iniciales
data1=data1.drop(index=[0,1,2,3,4,5,6])

# Restablecer el índice
data1.reset_index(drop=True, inplace=True)

# Mostrar el DataFrame resultante
data1
# Out:
# 4  HDI rank                 Country Human Development Index (HDI)  NaN  \
# 0         1             Switzerland                          0.962 NaN
# 1         2                  Norway                          0.961 NaN
# 2         3                 Iceland                          0.959 NaN
# 3         4  Hong Kong, China (SAR)                          0.952 NaN
# 4         5               Australia                          0.951 NaN
# ..      ...                     ...                            ...  ..
# 61       62                Malaysia                          0.803 NaN
# 62       63                 Georgia                          0.802 NaN
# 63       63               Mauritius                          0.802 NaN
# 64       63                  Serbia                          0.802 NaN
# 65       66                Thailand                            0.8 NaN
#
# 4  Life expectancy at birth  NaN Expected years of schooling  NaN  \
# ...

# %%
# Eliminar las primeras 4 filas
data_1= data1.drop(index=[0, 1, 2, 3])

# Restablecer el índice
data1.reset_index(drop=True, inplace=True)

# Mostrar el DataFrame resultante
data_1
# Out:
# 4  HDI rank    Country Human Development Index (HDI)  NaN  \
# 4         5  Australia                          0.951 NaN
# 5         6    Denmark                          0.948 NaN
# 6         7     Sweden                          0.947 NaN
# 7         8    Ireland                          0.945 NaN
# 8         9    Germany                          0.942 NaN
# ..      ...        ...                            ...  ..
# 61       62   Malaysia                          0.803 NaN
# 62       63    Georgia                          0.802 NaN
# 63       63  Mauritius                          0.802 NaN
# 64       63     Serbia                          0.802 NaN
# 65       66   Thailand                            0.8 NaN
#
# 4  Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 4                   84.5265  NaN                    21.05459    c
# 5                   81.3753  NaN                     18.7148    c
# 6                   82.9833  NaN                    19.41853    c
# ...

# %%
#Eliminacion de todas las filas que contengan valores NaN
data1_clean= data1[~(data1.iloc[:, 1:].isna().all(axis=1) & data1.iloc[:, 0].notna())]

data1_clean.head()
# Out:
# 4 HDI rank                 Country Human Development Index (HDI)  NaN  \
# 0        1             Switzerland                          0.962 NaN
# 1        2                  Norway                          0.961 NaN
# 2        3                 Iceland                          0.959 NaN
# 3        4  Hong Kong, China (SAR)                          0.952 NaN
# 4        5               Australia                          0.951 NaN
#
# 4 Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 0                  83.9872  NaN                   16.500299  NaN
# 1                  83.2339  NaN                     18.1852    c
# 2                  82.6782  NaN                   19.163059    c
# 3                  85.4734    d                    17.27817  NaN
# 4                  84.5265  NaN                    21.05459    c
#
# 4 Mean years of schooling  NaN Gross national income (GNI) per capita  NaN  \
# ...

# %%
# Eliminación de columnas que contienen NaN en la primera fila
data1_clean = data1_clean.loc[:, data1_clean.iloc[0].notna()]


# Reiniciar el índice del DataFrame
data1_clean.reset_index(drop=True, inplace=True)

# Mostrar el DataFrame resultante
data1_clean.head(5)
# Out:
# 4 HDI rank                 Country  Human Development Index (HDI)   \
# 0        1             Switzerland                           0.962
# 1        2                  Norway                           0.961
# 2        3                 Iceland                           0.959
# 3        4  Hong Kong, China (SAR)                           0.952
# 4        5               Australia                           0.951
#
# 4  Life expectancy at birth  Expected years of schooling  \
# 0                   83.9872                    16.500299
# 1                   83.2339                    18.185200
# 2                   82.6782                    19.163059
# 3                   85.4734                    17.278170
# 4                   84.5265                    21.054590
#
# 4  Mean years of schooling  Gross national income (GNI) per capita  \
# 0                 13.85966                             66933.00454
# 1                 13.00363                             64660.10622
# ...

# %%
data1_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 10 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   HDI rank                                66 non-null     object
#  1   Country                                 66 non-null     object
#  2   Human Development Index (HDI)           66 non-null     float64
#  3   Life expectancy at birth                66 non-null     float64
#  4   Expected years of schooling             66 non-null     float64
#  5   Mean years of schooling                 66 non-null     float64
#  6   Gross national income (GNI) per capita  66 non-null     float64
#  7   GNI per capita rank minus HDI rank      66 non-null     int64
#  8   HDI rank 2020                           66 non-null     int64
#  9   nan                                     66 non-null     object
# dtypes: float64(5), int64(2), object(3)
# ...

# %%
# Convertir las columnas de la 2 a la 7 a números
for col in data1_clean.columns[2:8]:
    data1_clean[col] = pd.to_numeric(data1_clean[col], errors='coerce')  # Convertir a float64

# Verificar el resultado
data1_clean
# Out:
# 4  HDI rank                 Country  Human Development Index (HDI)   \
# 0         1             Switzerland                           0.962
# 1         2                  Norway                           0.961
# 2         3                 Iceland                           0.959
# 3         4  Hong Kong, China (SAR)                           0.952
# 4         5               Australia                           0.951
# ..      ...                     ...                             ...
# 61       62                Malaysia                           0.803
# 62       63                 Georgia                           0.802
# 63       63               Mauritius                           0.802
# 64       63                  Serbia                           0.802
# 65       66                Thailand                           0.800
#
# 4   Life expectancy at birth  Expected years of schooling  \
# 0                    83.9872                    16.500299
# ...

# %%
data1_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 10 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   HDI rank                                66 non-null     object
#  1   Country                                 66 non-null     object
#  2   Human Development Index (HDI)           66 non-null     float64
#  3   Life expectancy at birth                66 non-null     float64
#  4   Expected years of schooling             66 non-null     float64
#  5   Mean years of schooling                 66 non-null     float64
#  6   Gross national income (GNI) per capita  66 non-null     float64
#  7   GNI per capita rank minus HDI rank      66 non-null     int64
#  8   HDI rank 2020                           66 non-null     int64
#  9   nan                                     66 non-null     object
# dtypes: float64(5), int64(2), object(3)
# ...

# %%
#Limpieza file4
data4 = pd.read_excel(file4, header=None)
encabezado=data4.iloc[0]
data4.columns=encabezado
data4 = data4.drop(index=0)
data4.reset_index(drop=True, inplace=True)


data4.head(7)
# Out:
# 0 HDI rank                        Country                    NaN  \
# 0      160  Tanzania (United Republic of)  LOW HUMAN DEVELOPMENT
# 1      161                       Pakistan  LOW HUMAN DEVELOPMENT
# 2      162                           Togo  LOW HUMAN DEVELOPMENT
# 3      163                          Haiti  LOW HUMAN DEVELOPMENT
# 4      163                        Nigeria  LOW HUMAN DEVELOPMENT
# 5      165                         Rwanda  LOW HUMAN DEVELOPMENT
# 6      166                          Benin  LOW HUMAN DEVELOPMENT
#
# 0 Human Development Index (HDI)  Life expectancy at birth  \
# 0                          0.549                  66.2007
# 1                          0.544                  66.0979
# 2                          0.539                  61.6194
# 3                          0.535                  63.1924
# 4                          0.535                   52.676
# 5                          0.534                  66.0722
# ...

# %%
data4_clean= data4[~(data4.iloc[:, 2:].isna().all(axis=1) & data4.iloc[:, 1].notna())]  #eliminar filas con NaN
data4_clean = data4_clean.loc[:, data4_clean.iloc[0].notna()]   #eliminar columna con NaN
data4_clean.reset_index(drop=True, inplace=True)
data4_clean.head()
# Out:
# 0 HDI rank                        Country                    NaN  \
# 0      160  Tanzania (United Republic of)  LOW HUMAN DEVELOPMENT
# 1      161                       Pakistan  LOW HUMAN DEVELOPMENT
# 2      162                           Togo  LOW HUMAN DEVELOPMENT
# 3      163                          Haiti  LOW HUMAN DEVELOPMENT
# 4      163                        Nigeria  LOW HUMAN DEVELOPMENT
#
# 0 Human Development Index (HDI)  Life expectancy at birth  \
# 0                          0.549                  66.2007
# 1                          0.544                  66.0979
# 2                          0.539                  61.6194
# 3                          0.535                  63.1924
# 4                          0.535                   52.676
#
# 0 Expected years of schooling Mean years of schooling  \
# 0                     9.22149                6.372899
# 1                     8.65835                 4.53633
# 2                   12.950494                5.016807
# ...

# %%
for col in data4_clean.columns[3:9]:
    data4_clean[col] = pd.to_numeric(data4_clean[col], errors='coerce')
data4_clean.head()
data4_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   HDI rank                                32 non-null     object
#  1   Country                                 32 non-null     object
#  2   nan                                     32 non-null     object
#  3   Human Development Index (HDI)           32 non-null     float64
#  4   Life expectancy at birth                32 non-null     float64
#  5   Expected years of schooling             32 non-null     float64
#  6   Mean years of schooling                 32 non-null     float64
#  7   Gross national income (GNI) per capita  32 non-null     float64
#  8   GNI per capita rank minus HDI rank      32 non-null     int64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 2.4+ KB

# %%
#limpieza file2
data2 = pd.read_excel(file2, header=None)
data2.loc[0, 11] = "HDI rank 2020"
encabezado=data2.iloc[0]
data2.columns=encabezado

data2= data2.drop(index=[0, 1, 2])
data2.reset_index(drop=True, inplace=True)

data2_clean= data2[~(data2.iloc[:, 1:].isna().all(axis=1) & data2.iloc[:, 0].notna())]  #eliminar filas con NaN
data2_clean = data2_clean.loc[:, data2_clean.iloc[0].notna()]   #eliminar columna con NaN
data2_clean = data2_clean.drop(columns=data2.columns[6])   #tiene valores adicionales al NaN
data2_clean.reset_index(drop=True, inplace=True)

for col in data2_clean.columns[2:8]:
    data2_clean[col] = pd.to_numeric(data2_clean[col], errors='coerce')

data2_clean.head()

data2_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   HDI rank                                49 non-null     object
#  1   Country                                 49 non-null     object
#  2   Human Development Index (HDI)           49 non-null     float64
#  3   Life expectancy at birth                49 non-null     float64
#  4   Expected years of schooling             49 non-null     float64
#  5   Mean years of schooling                 49 non-null     float64
#  6   Gross national income (GNI) per capita  49 non-null     float64
#  7   GNI per capita rank minus HDI rank      49 non-null     int64
#  8   HDI rank 2020                           49 non-null     object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 3.6+ KB

# %%
# limpieza file 3
data3 = pd.read_excel(file3, header=None)
data3.loc[0, 14] = "HDI rank 2020"
encabezado=data3.iloc[0]
data3.columns=encabezado

data3= data3.drop(index=[0, 1, 2])
data3.reset_index(drop=True, inplace=True)

data3_clean= data3[~(data3.iloc[:, 1:].isna().all(axis=1) & data3.iloc[:, 0].notna())]  #eliminar filas con NaN
data3_clean = data3_clean.loc[:, data3_clean.iloc[0].notna()]   #eliminar columna con NaN
data3_clean.reset_index(drop=True, inplace=True)

for col in data3_clean.columns[2:9]:
    data3_clean[col] = pd.to_numeric(data3_clean[col], errors='coerce')



#data3_clean = data3_clean.drop(columns=data3.columns[8])

data3_clean.head()
# Out:
# 0 HDI rank                             Country  \
# 0      116                         Philippines
# 1      117                            Botswana
# 2      118    Bolivia (Plurinational State of)
# 3      118                          Kyrgyzstan
# 4      120  Venezuela (Bolivarian Republic of)
#
# 0  Human Development Index (HDI)   Life expectancy at birth  \
# 0                           0.699                   69.2664
# 1                           0.693                   61.1409
# 2                           0.692                   63.6304
# 3                           0.692                   69.9774
# 4                           0.691                   70.5536
#
# 0  Expected years of schooling  Mean years of schooling  \
# 0                    13.126570                 8.969100
# 1                    12.265138                10.340000
# 2                    14.946971                 9.827750
# 3                    13.195300                11.374106
# ...

# %%
data3_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   HDI rank                                44 non-null     object
#  1   Country                                 44 non-null     object
#  2   Human Development Index (HDI)           44 non-null     float64
#  3   Life expectancy at birth                44 non-null     float64
#  4   Expected years of schooling             44 non-null     float64
#  5   Mean years of schooling                 44 non-null     float64
#  6   Gross national income (GNI) per capita  44 non-null     float64
#  7   GNI per capita rank minus HDI rank      44 non-null     int64
#  8   HDI rank 2020                           44 non-null     int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 3.2+ KB

# %% [markdown]
# INTEGRACIÓN DE DFs

# %%
# creación de lista de los 4 data frames
import pandas as pd

DFs=[data1_clean,data2_clean,data3_clean,data4_clean]

# %%
# guardando los nombres de las columnas
allColumnNames=[]
for df in DFs:
    allColumnNames.append(set(df.columns))

# verificando si tienen la misma cantidad
[len(cols) for cols in allColumnNames]
# Out:
# [10, 9, 9, 9]

# %%
# detalle de columnas en común
commonColumns=set.intersection(*allColumnNames)
len(commonColumns),commonColumns
# Out:
# (8,
#  {'Country',
#   'Expected years of schooling',
#   'GNI per capita rank minus HDI rank',
#   'Gross national income (GNI) per capita',
#   'HDI rank',
#   'Human Development Index (HDI) ',
#   'Life expectancy at birth',
#   'Mean years of schooling'})

# %%
# columna diferente
set.union(*allColumnNames)-commonColumns
# Out:
# {'HDI rank 2020', nan}

# %%
#eliminar esa columna
allDFs_sameNames=[df.loc[:,list(commonColumns)] for df in DFs]
len(allDFs_sameNames)
# Out:
# 4

# %%
#concatenar
#allDFs_sameNames=[df.loc[:,list(commonColumns)] for df in DFs]
allDFsConcat = pd.concat(allDFs_sameNames, ignore_index=True)
allDFsConcat
# Out:
#      Gross national income (GNI) per capita  Human Development Index (HDI)   \
# 0                              66933.004540                           0.962
# 1                              64660.106220                           0.961
# 2                              55782.049810                           0.959
# 3                              62606.845400                           0.952
# 4                              49238.433350                           0.951
# ..                                      ...                             ...
# 186                              731.786709                           0.426
# 187                              966.058611                           0.404
# 188                             1239.866936                           0.400
# 189                             1364.169417                           0.394
# 190                              767.787000                           0.385
#
# ...

# %%
allDFsConcat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Gross national income (GNI) per capita  191 non-null    float64
#  1   Human Development Index (HDI)           191 non-null    float64
#  2   Expected years of schooling             191 non-null    float64
#  3   GNI per capita rank minus HDI rank      191 non-null    int64
#  4   Life expectancy at birth                191 non-null    float64
#  5   Country                                 191 non-null    object
#  6   HDI rank                                191 non-null    object
#  7   Mean years of schooling                 191 non-null    float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 12.1+ KB

# %%
#limpieza de nombres de paises
# ubicar paises con nombres varios
allDFsConcat['Country'] = allDFsConcat['Country'].str.replace(r'\([^)]*\)', '', regex=True)
allDFsConcat['Country'] = allDFsConcat['Country'].str.split(',').str[0]
allDFsConcat['Country'] = allDFsConcat['Country'].str.upper()
allDFsConcat.head(5)
# Out:
#    Gross national income (GNI) per capita  Human Development Index (HDI)   \
# 0                             66933.00454                           0.962
# 1                             64660.10622                           0.961
# 2                             55782.04981                           0.959
# 3                             62606.84540                           0.952
# 4                             49238.43335                           0.951
#
#    Expected years of schooling  GNI per capita rank minus HDI rank  \
# 0                    16.500299                                   5
# 1                    18.185200                                   6
# 2                    19.163059                                  11
# 3                    17.278170                                   6
# 4                    21.054590                                  18
#
#    Life expectancy at birth      Country HDI rank  Mean years of schooling
# ...

# %% [markdown]
# MERGING

# %%
link1="https://github.com/Lorbe277/Control3_ICDE/raw/main/countryCODES.xlsx"

import pandas as pd
# Tabla CountryCODES
country=pd.read_excel(link1, header=None)
country
# Out:
#                0                                            1              2  \
# 0        Country                            Officialstatename  InternetccTLD
# 1    AFGHANISTAN          The Islamic Republic of Afghanistan            .af
# 2        ALBANIA                      The Republic of Albania            .al
# 3        ALGERIA  The People's Democratic Republic of Algeria            .dz
# 4         ANGOLA                       The Republic of Angola            .ao
# ..           ...                                          ...            ...
# 167   UZBEKISTAN                   The Republic of Uzbekistan            .uz
# 168     VIET NAM           The Socialist Republic of Viet Nam            .vn
# 169        YEMEN                        The Republic of Yemen            .ye
# 170       ZAMBIA                       The Republic of Zambia            .zm
# 171     ZIMBABWE                     The Republic of Zimbabwe            .zw
#
#         3     4
# 0    iso2  iso3
# ...

# %%
encabezado1=country.iloc[0]
country.columns=encabezado1
country
# Out:
# 0        Country                            Officialstatename  InternetccTLD  \
# 0        Country                            Officialstatename  InternetccTLD
# 1    AFGHANISTAN          The Islamic Republic of Afghanistan            .af
# 2        ALBANIA                      The Republic of Albania            .al
# 3        ALGERIA  The People's Democratic Republic of Algeria            .dz
# 4         ANGOLA                       The Republic of Angola            .ao
# ..           ...                                          ...            ...
# 167   UZBEKISTAN                   The Republic of Uzbekistan            .uz
# 168     VIET NAM           The Socialist Republic of Viet Nam            .vn
# 169        YEMEN                        The Republic of Yemen            .ye
# 170       ZAMBIA                       The Republic of Zambia            .zm
# 171     ZIMBABWE                     The Republic of Zimbabwe            .zw
#
# 0    iso2  iso3
# 0    iso2  iso3
# ...

# %%
# merge de ambas DFs
merge=allDFsConcat.merge(country,left_on='Country',right_on='Country')
merge
# Out:
#      Gross national income (GNI) per capita  Human Development Index (HDI)   \
# 0                              66933.004540                           0.962
# 1                              64660.106220                           0.961
# 2                              55782.049810                           0.959
# 3                              49238.433350                           0.951
# 4                              60364.785950                           0.948
# ..                                      ...                             ...
# 141                             1198.073924                           0.446
# 142                             2132.629443                           0.428
# 143                              731.786709                           0.426
# 144                             1364.169417                           0.394
# 145                              767.787000                           0.385
#
# ...

# %% [markdown]
# FALLECIDOS COVID

# %%
link2="https://github.com/Lorbe277/Control3_ICDE/raw/main/fallecidosCOVID.csv"

fallecidosC=pd.read_csv(link2)
fallecidosC
# Out:
#        FECHA_CORTE;FECHA_FALLECIMIENTO;EDAD_DECLARADA;SEXO;CLASIFICACION_DEF;DEPARTAMENTO;PROVINCIA;DISTRITO;UBIGEO;UUID
# 0       20240317;20220219;63;MASCULINO;Criterio viroló...
# 1       20240317;20210529;74;MASCULINO;Criterio viroló...
# 2       20240317;20210623;72;FEMENINO;Criterio SINADEF...
# 3       20240317;20210824;85;MASCULINO;Criterio invest...
# 4       20240317;20210627;46;MASCULINO;Criterio viroló...
# ...                                                   ...
# 220913  20240317;20200809;77;MASCULINO;Criterio radiol...
# 220914  20240317;20201028;81;MASCULINO;Criterio clínic...
# 220915  20240317;20200515;68;FEMENINO;Criterio SINADEF...
# 220916  20240317;20210414;66;FEMENINO;Criterio clínico...
# 220917  20240317;20200819;61;MASCULINO;Criterio nexo e...
#
# [220918 rows x 1 columns]

# %%
fallecidosC.shape
# Out:
# (220918, 1)
